# %% [markdown]
# # Data Science tools and Ecosystem

# %% [markdown]
# In this notebook, data science and tools ans ecosystem are summarized

# %% [markdown]
# Some popular languages that data scientist use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
# 7. Julia
# 8. JavaScript
# 9. PHP
# 10. Go
# 11. Ruby
# 12. Visual Basic

# %% [markdown]
# Some popular libraries that data scientist, including:
#
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Keras
# 7. TensorFlow
# 8. PyTorch
# 9. Apache Spark
# 10. Vegas
# 11. Big DL
# 12. Ggplot2

# %% [markdown]
# Data Science Tools
#
# | Tool          |
# |---------------|
# | Jupyter Notebook |
# | R studio       |
# | Spyder      |
# | Apache Hadoop |
# | Spark         |

# %% [markdown]
# Below are few arithmetic operation in python

# %%
#this is simple arithmetic operation
(4*5)-3
# Out:
# 17

# %%
#this will convert 200 min to hours by dividing 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives**

# %% [markdown]
# - Learn the basics of Data Science languages.
# - Understand key Data Science libraries.
# - Explore tools commonly used in the Data Science field.
# - Demonstrate arithmetic operations and conversions.

# %% [markdown]
# ## Author
#
# Mushtaque
#   Ali
